# %%
#Find a .csv dataset online and import it into a new notebook. Once you have your data imported, play around with 
#the functions that you've learned thus far. What information can you find out about your dataset? Write a brief 
#summary about the characteristics of your dataset: what kind of data was collected, how large is the dataset, how 
#many columns/rows, what are the names of the columns, what types of data are included in the dataset, etc. Can you 
#isolate a slice of your data and export it to a new .csv file?

# %%
#https://www.kaggle.com/siropo/spotify-multigenre-playlists-data
#Title: Spotify Multi-Genre Playlists Data
#Author: Ido Lior
#Files: alternative_music_data.csv
#       blues_music_data.csv
#       hiphop_music_data.csv
#       indie_alt_music_data.csv
#       metal_music_data.csv
#       pop_music_data.csv
#       rock_music_data.csv

# %%
import pandas as pd

# %%
#import "alternative_music_data.csv" file/dataset into a variable
#display information in the variable

alt_music_data = pd.read_csv("spotifydatasets/alternative_music_data.csv")
alt_music_data
# Out:
#           Artist Name                 Track Name  Popularity  \
# 0               James                       Laid          66
# 1            grandson            In Over My Head          60
# 2               Foals                On The Luna          51
# 3            Longpigs                   She Said          47
# 4        Beastie Boys                  Sure Shot          57
# ...               ...                        ...         ...
# 2155        The Shins                  So Says I          51
# 2156  Yeah Yeah Yeahs                  Gold Lion          54
# 2157  Lianne La Havas  Seven Times - Wu-Lu Remix          53
# 2158         Sløtface                   Luminous          27
# 2159   *repeat repeat            Wind in My Sail          23
#
#                                                  Genres             Playlist  \
# 0     ['britpop', 'madchester', 'new wave', 'new wav...      Alternative 90s
# ...

# %%
#view column information from the file/dataset including column name & data type

alt_music_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2160 entries, 0 to 2159
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Artist Name       2160 non-null   object
#  1   Track Name        2160 non-null   object
#  2   Popularity        2160 non-null   int64
#  3   Genres            2160 non-null   object
#  4   Playlist          2160 non-null   object
#  5   danceability      2160 non-null   float64
#  6   energy            2160 non-null   float64
#  7   key               2160 non-null   int64
#  8   loudness          2160 non-null   float64
#  9   mode              2160 non-null   int64
#  10  speechiness       2160 non-null   float64
#  11  acousticness      2160 non-null   float64
#  12  instrumentalness  2160 non-null   float64
#  13  liveness          2160 non-null   float64
#  14  valence           2160 non-null   float64
#  15  tempo             2160 non-null   float64
# ...

# %%
#view statistical data of the columns with numeric values (mean, min, max, stdev, quartile(s), count)

alt_music_data.describe()
# Out:
#         Popularity  danceability       energy          key     loudness  \
# count  2160.000000   2160.000000  2160.000000  2160.000000  2160.000000
# mean     46.292593      0.536953     0.693046     5.355556    -7.623776
# std      15.709455      0.157916     0.212345     3.569007     3.831861
# min       0.000000      0.063500     0.003010     0.000000   -33.838000
# 25%      37.000000      0.434000     0.569000     2.000000    -9.070500
# 50%      46.000000      0.543500     0.726000     6.000000    -6.913500
# 75%      57.000000      0.644000     0.870250     9.000000    -5.213750
# max      89.000000      0.982000     0.998000    11.000000     1.342000
#
#               mode  speechiness  acousticness  instrumentalness     liveness  \
# count  2160.000000  2160.000000   2160.000000       2160.000000  2160.000000
# mean      0.658796     0.067556      0.177995          0.164318     0.188587
# std       0.474223     0.065370      0.263960          0.292144     0.141501
# ...

# %%
#view the first 10 rows of the dataset/file

alt_music_data.head(10)
# Out:
#            Artist Name          Track Name  Popularity  \
# 0                James                Laid          66
# 1             grandson     In Over My Head          60
# 2                Foals         On The Luna          51
# 3             Longpigs            She Said          47
# 4         Beastie Boys           Sure Shot          57
# 5            Castaways          Liar, Liar          40
# 6  Justin Townes Earle  Ain’t Got No Money          57
# 7       Parquet Courts   Human Performance          47
# 8     The Replacements         I Will Dare          47
# 9                Mourn  Fun at the Geysers          25
#
#                                               Genres             Playlist  \
# 0  ['britpop', 'madchester', 'new wave', 'new wav...      Alternative 90s
# 1  ['modern alternative rock', 'modern rock', 'ro...    Alternative Beats
# 2  ['alternative dance', 'indie rock', 'modern al...      Alternative 10s
# ...

# %%
#view the last 10 rows of the dataset/file

alt_music_data.tail(10)
# Out:
#             Artist Name                    Track Name  Popularity  \
# 2150        Eryn Martin                  Ball - Remix          45
# 2151            Jayda G  All I Need (DJ-Kicks) - Edit          61
# 2152              Salem                     DRACULADS          40
# 2153         Gary Numan                          Cars          64
# 2154  Twenty One Pilots                      Jumpsuit          71
# 2155          The Shins                     So Says I          51
# 2156    Yeah Yeah Yeahs                     Gold Lion          54
# 2157    Lianne La Havas     Seven Times - Wu-Lu Remix          53
# 2158           Sløtface                      Luminous          27
# 2159     *repeat repeat               Wind in My Sail          23
#
#                                                  Genres              Playlist  \
# 2150                                                 []              Outliers
# 2151                            ['canadian electronic']              Outliers
# ...

# %%
#save the first 10 rows of the dataset into another variable (name)

alt_music_data_slice = alt_music_data.head(10)
alt_music_data_slice
# Out:
#            Artist Name          Track Name  Popularity  \
# 0                James                Laid          66
# 1             grandson     In Over My Head          60
# 2                Foals         On The Luna          51
# 3             Longpigs            She Said          47
# 4         Beastie Boys           Sure Shot          57
# 5            Castaways          Liar, Liar          40
# 6  Justin Townes Earle  Ain’t Got No Money          57
# 7       Parquet Courts   Human Performance          47
# 8     The Replacements         I Will Dare          47
# 9                Mourn  Fun at the Geysers          25
#
#                                               Genres             Playlist  \
# 0  ['britpop', 'madchester', 'new wave', 'new wav...      Alternative 90s
# 1  ['modern alternative rock', 'modern rock', 'ro...    Alternative Beats
# 2  ['alternative dance', 'indie rock', 'modern al...      Alternative 10s
# ...

# %%
#save the 10 rows into a file located in the "spotifydatasets" folder

alt_music_data_slice.to_csv("spotifydatasets/alt_music_slice",index=False)
